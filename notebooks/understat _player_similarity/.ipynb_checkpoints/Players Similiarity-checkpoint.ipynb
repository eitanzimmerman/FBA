# %% [markdown]
# # Players Similirity Analysis

# %%
## Importing Packeges
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %%
players_data = pd.read_csv('../../data/understat_players_df.csv')

# %% [markdown]
# #### Coloring Configs

# %%
plt.rcParams["figure.figsize"] = (10,10)
sns.set(style="darkgrid")

# %% [markdown]
# ## Data Pre Processing

# %%
## Getting full season data
max_per_season_and_league = players_data.groupby(["League", "Season"]).agg({"aggregated_to_match":"max"}).reset_index()
players_df = pd.merge(players_data, max_per_season_and_league, on=["League", "Season", "aggregated_to_match"], how="inner")

players_df.head()
# Out:
#      id        player_name  games  time  goals         xG  assists         xA  \
# 0  2371  Cristiano Ronaldo     35  3103     48  39.308761       16  13.600642
# 1  2097       Lionel Messi     38  3374     43  35.891764       18  17.611956
# 2  2099             Neymar     33  2573     22  22.721618        7   8.261543
# 3  2270  Antoine Griezmann     37  2490     22  14.709662        1   2.607721
# 4  1125       Carlos Bacca     36  2491     20  19.222722        6   4.423763
#
#    shots  key_passes  ...  red_cards  position       team_title npg  \
# 0    225          76  ...          1       F M      Real Madrid  38
# 1    187          95  ...          0       F S        Barcelona  38
# 2     95          52  ...          0       F S        Barcelona  21
# 3     78          23  ...          0     F M S  Atletico Madrid  22
# 4     68          29  ...          0       F S          Sevilla  14
#
#         npxG    xGChain  xGBuildup   League Season  aggregated_to_match
# 0  30.389686  43.608020   7.520237  La_liga   2014                   38
# 1  31.432098  54.753610  19.756724  La_liga   2014                   38
# 2  21.978340  36.888220  11.678407  La_liga   2014                   38
# 3  14.709662  18.479452   4.551564  La_liga   2014                   38
# 4  13.277143  15.749522   2.668241  La_liga   2014                   38
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Filtering

# %%
## Filtering players that didn't play at all.
time_threshold = 5 * 90
players_df = players_df[players_df["time"] > time_threshold]

## Removing Goals Keeprs 
players_df = players_df[~players_df["position"].str.contains("GK")]

# %%
players_df.head().T
# Out:
#                                      0             1          2  \
# id                                2371          2097       2099
# player_name          Cristiano Ronaldo  Lionel Messi     Neymar
# games                               35            38         33
# time                              3103          3374       2573
# goals                               48            43         22
# xG                           39.308761     35.891764  22.721618
# assists                             16            18          7
# xA                           13.600642     17.611956   8.261543
# shots                              225           187         95
# key_passes                          76            95         52
# yellow_cards                         5             4          6
# red_cards                            1             0          0
# position                           F M           F S        F S
# team_title                 Real Madrid     Barcelona  Barcelona
# npg                                 38            38         21
# npxG                         30.389686     31.432098   21.97834
# xGChain                       43.60802      54.75361   36.88822
# xGBuildup                     7.520237     19.756724  11.678407
# League                         La_liga       La_liga    La_liga
# Season                            2014          2014       2014
# aggregated_to_match                 38            38         38
#
#                                      3             4
# id                                2270          1125
# player_name          Antoine Griezmann  Carlos Bacca
# games                               37            36
# time                              2490          2491
# goals                               22            20
# xG                           14.709662     19.222722
# assists                              1             6
# xA                            2.607721      4.423763
# shots                               78            68
# key_passes                          23            29
# yellow_cards                         6             4
# red_cards                            0             0
# position                         F M S           F S
# team_title             Atletico Madrid       Sevilla
# npg                                 22            14
# npxG                         14.709662     13.277143
# xGChain                      18.479452     15.749522
# xGBuildup                     4.551564      2.668241
# League                         La_liga       La_liga
# Season                            2014          2014
# aggregated_to_match                 38            38

# %% [markdown]
# ### Extracting features

# %%
players_df["time_played_ratio"] = players_df["time"]/(players_df["aggregated_to_match"] * 90)
players_df["npxG_to_npg_diff"] = players_df["npg"] - players_df["npxG"]
players_df["shots_success_rate"] = players_df["goals"] / players_df["shots"]

# %% [markdown]
# ### Normalizing Data per game

# %%
cols_to_normalize = [
    "npg",
    "npxG",
    "assists",
    "xA",
    "shots",
    "key_passes",
    "xGChain",
    "xGBuildup",
    "npxG_to_npg_diff"
]

for col in cols_to_normalize:
    players_df[f"{col}_pg"] = players_df[col] / (players_df["time"] / 90)

# %% [markdown]
# ### Visualizing features distribution

# %%
fig, axs = plt.subplots(3, 3, figsize=(12,12))

features_to_plot = [("npxG_pg", "xG per game", "olive"), 
                    ("xA_pg", "xA per game", "skyblue"), 
                    ("shots_pg", "Shots per game", "teal"), 
                    ('key_passes_pg', 'Key passes per game', "olive"),
                    ('npxG_to_npg_diff', "Hard goals per game", "skyblue"), 
                    ('time_played_ratio', "Effective time exploit", "teal"),
                    ('shots_success_rate', "Goals per shot", "olive"),
                    ('xGBuildup_pg', "Goals buildup contribution per game", "skyblue"),
                    ('xGChain_pg', "Goals chaining per game", "teal")]

for idx,ax in enumerate(np.ravel(axs)):
    col, title, color = features_to_plot[idx]
    non_zero_subset = players_df[players_df[col] > 0] if col != "npxG_to_npg_diff" else players_df
    ax = sns.histplot(data=non_zero_subset, x=f"{col}", kde=True, color=f"{color}",stat="density", ax=ax)
    ax.set_title(title, fontsize=12)
    ax.set_yticks([])
    ax.set_xlabel("")
    for spine in ['right', 'top', 'left']:
        ax.spines[spine].set_visible(False)
fig.tight_layout()

# %% [markdown]
# ### Ronaldo and Messi xG

# %%
elite = players_df["id"].apply(lambda _id: _id in [2371, 2097])

pairs = [("npxG_pg", "time_played_ratio"),
         ("npxG_pg", "xA_pg"),
         ("xGChain_pg", "xGBuildup_pg"),
         ("npxG_pg", "key_passes_pg")
        ]

for pair in pairs:
    col1, col2 = pair
    g = sns.jointplot(data=players_df, x=col1,y=col2, hue="position",alpha=0.5, 
                      kind="scatter", ax=ax, legend=False)


plt.show()

# %% [markdown]
# ### Additional data wrangling

# %%
players_df["player_name_season"] = players_df["player_name"] + "_" + players_df["Season"].astype('str')

# %% [markdown]
# # Similiraity analysis

# %% [markdown]
# ### Quantile Representations

# %% [markdown]
# Transforming Per game stats to quantiles representation

# %%
players_df.head().T
# Out:
#                                           0                  1            2  \
# id                                     2371               2097         2099
# player_name               Cristiano Ronaldo       Lionel Messi       Neymar
# games                                    35                 38           33
# time                                   3103               3374         2573
# goals                                    48                 43           22
# xG                                39.308761          35.891764    22.721618
# assists                                  16                 18            7
# xA                                13.600642          17.611956     8.261543
# shots                                   225                187           95
# key_passes                               76                 95           52
# yellow_cards                              5                  4            6
# red_cards                                 1                  0            0
# position                                F M                F S          F S
# team_title                      Real Madrid          Barcelona    Barcelona
# npg                                      38                 38           21
# npxG                              30.389686          31.432098     21.97834
# xGChain                            43.60802           54.75361     36.88822
# xGBuildup                          7.520237          19.756724    11.678407
# League                              La_liga            La_liga      La_liga
# Season                                 2014               2014         2014
# aggregated_to_match                      38                 38           38
# time_played_ratio                   0.90731            0.98655     0.752339
# npxG_to_npg_diff                   7.610314           6.567902     -0.97834
# shots_success_rate                 0.213333           0.229947     0.231579
# npg_pg                             1.102159           1.013634     0.734551
# npxG_pg                            0.881428           0.838438     0.768772
# assists_pg                         0.464067           0.480142      0.24485
# xA_pg                              0.394476           0.469791     0.288977
# shots_pg                           6.525943           4.988145     3.322969
# key_passes_pg                      2.204318           2.534084     1.818888
# xGChain_pg                         1.264815           1.460529     1.290299
# xGBuildup_pg                       0.218118           0.527002     0.408495
# npxG_to_npg_diff_pg                0.220731           0.175196    -0.034221
# player_name_season   Cristiano Ronaldo_2014  Lionel Messi_2014  Neymar_2014
#
#                                           3                  4
# id                                     2270               1125
# player_name               Antoine Griezmann       Carlos Bacca
# games                                    37                 36
# time                                   2490               2491
# goals                                    22                 20
# xG                                14.709662          19.222722
# assists                                   1                  6
# xA                                 2.607721           4.423763
# shots                                    78                 68
# key_passes                               23                 29
# yellow_cards                              6                  4
# red_cards                                 0                  0
# position                              F M S                F S
# team_title                  Atletico Madrid            Sevilla
# npg                                      22                 14
# npxG                              14.709662          13.277143
# xGChain                           18.479452          15.749522
# xGBuildup                          4.551564           2.668241
# League                              La_liga            La_liga
# Season                                 2014               2014
# aggregated_to_match                      38                 38
# time_played_ratio                   0.72807           0.728363
# npxG_to_npg_diff                   7.290338           0.722857
# shots_success_rate                 0.282051           0.294118
# npg_pg                             0.795181           0.505821
# npxG_pg                            0.531675           0.479704
# assists_pg                         0.036145            0.21678
# xA_pg                              0.094255           0.159831
# shots_pg                           2.819277           2.456845
# key_passes_pg                      0.831325           1.047772
# xGChain_pg                         0.667932           0.569031
# xGBuildup_pg                       0.164514           0.096404
# npxG_to_npg_diff_pg                0.263506           0.026117
# player_name_season   Antoine Griezmann_2014  Carlos Bacca_2014

# %%
from sklearn.preprocessing import quantile_transform

analysis_df = pd.DataFrame()

## Add meta columns
analysis_df["player_name"] = players_df["player_name_season"]
analysis_df["Season"] = players_df["Season"]
analysis_df["League"] = players_df["League"]

## Quantile normalized columns
cols_to_normalize = [
    "npg_pg",
    "npxG_pg",
    "assists_pg",
    "xA_pg",
    "shots_pg",
    "key_passes_pg",
    "xGChain_pg",
    "xGBuildup_pg",
    "npxG_to_npg_diff"
]

for col in cols_to_normalize:
    analysis_df[f"{col.split('_')[0]}_q"] = quantile_transform(players_df[col].to_numpy().reshape(-1,1), 
                                                               n_quantiles=100,
                                                               random_state=0, 
                                                               copy=True)

## Stat columns

# %%
np.linspace(1, len(players_df), len(players_df)).reshape(-1,1)
# Out:
# array([[1.0000e+00],
#        [2.0000e+00],
#        [3.0000e+00],
#        ...,
#        [1.4284e+04],
#        [1.4285e+04],
#        [1.4286e+04]])

# %%
analysis_df['npxG_q'].sort_values()
# Out:
# 10364    0.000000
# 1657     0.001852
# 6035     0.004341
# 7521     0.004627
# 15698    0.004705
#            ...
# 5416     0.998149
# 13962    0.999167
# 1058     0.999181
# 2154     0.999906
# 17237    1.000000
# Name: npxG_q, Length: 14286, dtype: float64

# %%
i
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [15], in <module>
# ----> 1 import statsmodel
#
# ModuleNotFoundError: No module named 'statsmodel'

# %%
stats.cdf(analysis_df['npxG_q'].sort_values())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [227], in <module>
# ----> 1 stats.cdf(analysis_df['npxG_q'].sort_values())
#
# AttributeError: module 'scipy.stats' has no attribute 'cdf'
